# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaygwu/SEAS8525/blob/main/Class_2_CL_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The SimCLR approach aims to learn meaningful representations of images in a self-supervised manner. It does this by maximizing the cosine similarity between representations of augmented views of the same image (positive pairs) and minimizing the cosine similarity between representations of different images (negative pairs). The contrastive loss encourages the encoder to learn representations that are invariant to the applied data augmentations.
#
# The visualization using t-SNE allows us to assess the quality of the learned representations by observing how well the different classes are separated in the low-dimensional space.

# %% [markdown]
# This code demonstrates the implementation of a self-supervised learning approach called SimCLR (Simple Framework for Contrastive Learning of Visual Representations) using the CIFAR-10 dataset. Let's go through the code section by section:
#
# 1. Importing Libraries:
#    - The necessary libraries, including TensorFlow, Keras, Matplotlib, and scikit-learn, are imported.
#
# 2. Loading and Preprocessing Data:
#    - The CIFAR-10 dataset is loaded using `keras.datasets.cifar10.load_data()`.
#    - The pixel values of the training and testing data are normalized to the range [0, 1].
#    - The training data is converted into a TensorFlow Dataset using `tf.data.Dataset.from_tensor_slices()` and batched.
#
# 3. Data Augmentation:
#    - A data augmentation pipeline is defined using `keras.Sequential()` to apply random cropping, flipping, rescaling, and zooming to the input images.
#
# 4. Defining the Encoder Network:
#    - The `create_encoder` function defines the base encoder network using convolutional layers, max pooling, and a global max pooling layer.
#    - The encoder network takes an input image and outputs a 128-dimensional feature representation.
#
# 5. Defining the Projection Head:
#    - The `create_projection_head` function defines the projection head network using dense layers.
#    - The projection head takes the 128-dimensional feature representation from the encoder and projects it to a 128-dimensional space.
#
# 6. Training Loop:
#    - The training loop runs for a specified number of epochs.
#    - For each batch of training data:
#      - The encoder and projection head are applied to the batch of images.
#      - The resulting projected representations are L2-normalized.
#      - The cosine similarity matrix is computed between the normalized representations.
#      - The contrastive loss is calculated using the cosine similarity matrix and temperature scaling.
#      - The gradients of the loss with respect to the weights of the encoder and projection head are computed.
#      - The optimizer is used to update the weights of the encoder and projection head.
#
# 7. Extracting Representations:
#    - After training, the trained encoder is used to extract representations (embeddings) for the test images.
#
# 8. t-SNE Visualization:
#    - The t-SNE algorithm is used to reduce the dimensionality of the learned representations to 2D.
#    - The t-SNE results are plotted using Matplotlib, with each point colored according to its true class label.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load and preprocess the CIFAR-10 dataset
(x_train, _), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train, x_test = x_train.astype('float32') / 255.0, x_test.astype('float32') / 255.0

# Convert the training data into a TensorFlow Dataset
batch_size = 256
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(batch_size)

# Define the data augmentation function
data_augmentation = keras.Sequential([
    layers.RandomCrop(height=32, width=32),
    layers.RandomFlip("horizontal"),
    layers.Rescaling(1./255),
    layers.RandomZoom(0.2),
])

# Define the base encoder network
def create_encoder():
    inputs = layers.Input(shape=(32, 32, 3))
    x = data_augmentation(inputs)
    x = layers.Conv2D(32, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation='relu')(x)
    x = layers.GlobalMaxPooling2D()(x)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

# Define the projection head
def create_projection_head():
    inputs = keras.Input(shape=(128,))
    x = layers.Dense(256, activation='relu')(inputs)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

encoder = create_encoder()
projection_head = create_projection_head()

optimizer = keras.optimizers.Adam()
epochs = 100
temperature = 0.2

# Custom training loop
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    for step, x_batch_train in enumerate(train_dataset):
        with tf.GradientTape() as tape:
          #==================================================================================================
          # TensorFlow provides the tf.GradientTape API for automatic differentiation; that is, computing the gradient of a computation
          # with respect to some inputs, usually tf.Variables. TensorFlow "records" relevant operations executed inside the context of
          # a tf.GradientTape onto a "tape". TensorFlow then uses that tape to compute the gradients of a "recorded" computation using
          # reverse mode differentiation.
          #==================================================================================================
            # Forward pass
            encoded = encoder(x_batch_train, training=True)
            projected = projection_head(encoded, training=True)
            normalized = tf.math.l2_normalize(projected, axis=1)
            cosine_similarity = tf.matmul(normalized, normalized, transpose_b=True)
            logits = cosine_similarity / temperature
            labels = tf.range(x_batch_train.shape[0])
            loss_value = keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
            loss_value = tf.reduce_mean(loss_value)

        # Get gradients of loss wrt the weights.
        gradients = tape.gradient(loss_value, encoder.trainable_weights + projection_head.trainable_weights)

        # Update the weights of the encoder and projection head.
        optimizer.apply_gradients(zip(gradients, encoder.trainable_weights + projection_head.trainable_weights))

        if step % 100 == 0:
            print(f"Training loss (for one batch) at step {step}: {float(loss_value)}")

# Extract representations after training
representations = encoder.predict(x_test)

# t-SNE visualization
tsne = TSNE(n_components=2, perplexity=30, n_iter=3000)
tsne_results = tsne.fit_transform(representations)

plt.figure(figsize=(8, 8))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test.flatten(), cmap='rainbow')
plt.title('t-SNE Visualization of Learned Representations')
plt.colorbar()
plt.show()
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 5.4263458251953125
# Training loss (for one batch) at step 100: 3.5962085723876953
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 1.8628902435302734
# Training loss (for one batch) at step 100: 1.390346646308899
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 1.3102537393569946
# Training loss (for one batch) at step 100: 1.2475156784057617
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 1.245486855506897
# Training loss (for one batch) at step 100: 1.218853235244751
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 1.2149015665054321
# Training loss (for one batch) at step 100: 1.1763776540756226
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 1.1884188652038574
# Training loss (for one batch) at step 100: 1.153266191482544
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 1.150565505027771
# Training loss (for one batch) at step 100: 1.138267993927002
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 1.1448750495910645
# Training loss (for one batch) at step 100: 1.1230818033218384
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 1.131849765777588
# Training loss (for one batch) at step 100: 1.1176679134368896
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 1.1288189888000488
# Training loss (for one batch) at step 100: 1.1268752813339233
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 1.133007287979126
# Training loss (for one batch) at step 100: 1.1126326322555542
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 1.1139918565750122
# Training loss (for one batch) at step 100: 1.110736608505249
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 1.1091413497924805
# Training loss (for one batch) at step 100: 1.1043472290039062
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 1.1202465295791626
# Training loss (for one batch) at step 100: 1.11154043674469
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 1.103997826576233
# Training loss (for one batch) at step 100: 1.1103144884109497
#
# Start of epoch 15
# Training loss (for one batch) at step 0: 1.1193877458572388
# Training loss (for one batch) at step 100: 1.0982797145843506
#
# Start of epoch 16
# Training loss (for one batch) at step 0: 1.1051199436187744
# Training loss (for one batch) at step 100: 1.0980807542800903
#
# Start of epoch 17
# Training loss (for one batch) at step 0: 1.107386589050293
# Training loss (for one batch) at step 100: 1.100109577178955
#
# Start of epoch 18
# Training loss (for one batch) at step 0: 1.0975680351257324
# Training loss (for one batch) at step 100: 1.1026782989501953
#
# Start of epoch 19
# Training loss (for one batch) at step 0: 1.0924204587936401
# Training loss (for one batch) at step 100: 1.0889501571655273
#
# Start of epoch 20
# Training loss (for one batch) at step 0: 1.1062464714050293
# Training loss (for one batch) at step 100: 1.1024134159088135
#
# Start of epoch 21
# Training loss (for one batch) at step 0: 1.1015547513961792
# Training loss (for one batch) at step 100: 1.095582127571106
#
# Start of epoch 22
# Training loss (for one batch) at step 0: 1.0965451002120972
# Training loss (for one batch) at step 100: 1.093643069267273
#
# Start of epoch 23
# Training loss (for one batch) at step 0: 1.0943171977996826
# Training loss (for one batch) at step 100: 1.0915639400482178
#
# Start of epoch 24
# Training loss (for one batch) at step 0: 1.08272385597229
# Training loss (for one batch) at step 100: 1.096281886100769
#
# Start of epoch 25
# Training loss (for one batch) at step 0: 1.0938800573349
# Training loss (for one batch) at step 100: 1.0905847549438477
#
# Start of epoch 26
# Training loss (for one batch) at step 0: 1.0928763151168823
# Training loss (for one batch) at step 100: 1.089742660522461
#
# Start of epoch 27
# Training loss (for one batch) at step 0: 1.0866442918777466
# Training loss (for one batch) at step 100: 1.0895665884017944
#
# Start of epoch 28
# Training loss (for one batch) at step 0: 1.092392921447754
# Training loss (for one batch) at step 100: 1.0940407514572144
#
# Start of epoch 29
# Training loss (for one batch) at step 0: 1.0860650539398193
# Training loss (for one batch) at step 100: 1.0928266048431396
#
# Start of epoch 30
# Training loss (for one batch) at step 0: 1.0813606977462769
# Training loss (for one batch) at step 100: 1.092572808265686
#
# Start of epoch 31
# Training loss (for one batch) at step 0: 1.0952023267745972
# Training loss (for one batch) at step 100: 1.0894243717193604
#
# Start of epoch 32
# Training loss (for one batch) at step 0: 1.0869114398956299
# Training loss (for one batch) at step 100: 1.09097158908844
#
# Start of epoch 33
# Training loss (for one batch) at step 0: 1.0944674015045166
# Training loss (for one batch) at step 100: 1.0824785232543945
#
# Start of epoch 34
# Training loss (for one batch) at step 0: 1.081369400024414
# Training loss (for one batch) at step 100: 1.0849394798278809
#
# Start of epoch 35
# Training loss (for one batch) at step 0: 1.086391806602478
# Training loss (for one batch) at step 100: 1.0897618532180786
#
# Start of epoch 36
# Training loss (for one batch) at step 0: 1.0892353057861328
# Training loss (for one batch) at step 100: 1.0845036506652832
#
# Start of epoch 37
# Training loss (for one batch) at step 0: 1.0855510234832764
# Training loss (for one batch) at step 100: 1.0855040550231934
#
# Start of epoch 38
# Training loss (for one batch) at step 0: 1.0807526111602783
# Training loss (for one batch) at step 100: 1.0825703144073486
#
# Start of epoch 39
# Training loss (for one batch) at step 0: 1.083524465560913
# Training loss (for one batch) at step 100: 1.0800281763076782
#
# Start of epoch 40
# Training loss (for one batch) at step 0: 1.0839812755584717
# Training loss (for one batch) at step 100: 1.0880513191223145
#
# Start of epoch 41
# Training loss (for one batch) at step 0: 1.0839546918869019
# Training loss (for one batch) at step 100: 1.084244966506958
#
# Start of epoch 42
# Training loss (for one batch) at step 0: 1.086106777191162
# Training loss (for one batch) at step 100: 1.0911723375320435
#
# Start of epoch 43
# Training loss (for one batch) at step 0: 1.0823688507080078
# Training loss (for one batch) at step 100: 1.0895941257476807
#
# Start of epoch 44
# Training loss (for one batch) at step 0: 1.0795092582702637
# Training loss (for one batch) at step 100: 1.0821483135223389
#
# Start of epoch 45
# Training loss (for one batch) at step 0: 1.0805476903915405
# Training loss (for one batch) at step 100: 1.0860004425048828
#
# Start of epoch 46
# Training loss (for one batch) at step 0: 1.082659363746643
# Training loss (for one batch) at step 100: 1.085216760635376
#
# Start of epoch 47
# Training loss (for one batch) at step 0: 1.0898001194000244
# Training loss (for one batch) at step 100: 1.0774354934692383
#
# Start of epoch 48
# Training loss (for one batch) at step 0: 1.081873893737793
# Training loss (for one batch) at step 100: 1.0848627090454102
#
# Start of epoch 49
# Training loss (for one batch) at step 0: 1.0873963832855225
# Training loss (for one batch) at step 100: 1.082181453704834
#
# Start of epoch 50
# Training loss (for one batch) at step 0: 1.0805585384368896
# Training loss (for one batch) at step 100: 1.0805513858795166
#
# Start of epoch 51
# Training loss (for one batch) at step 0: 1.077133059501648
# Training loss (for one batch) at step 100: 1.087923288345337
#
# Start of epoch 52
# Training loss (for one batch) at step 0: 1.0866175889968872
# Training loss (for one batch) at step 100: 1.083387017250061
#
# Start of epoch 53
# Training loss (for one batch) at step 0: 1.083555817604065
# Training loss (for one batch) at step 100: 1.0875070095062256
#
# Start of epoch 54
# Training loss (for one batch) at step 0: 1.0838181972503662
# Training loss (for one batch) at step 100: 1.081987977027893
#
# Start of epoch 55
# Training loss (for one batch) at step 0: 1.0769126415252686
# Training loss (for one batch) at step 100: 1.0789759159088135
#
# Start of epoch 56
# Training loss (for one batch) at step 0: 1.0804955959320068
# Training loss (for one batch) at step 100: 1.0787051916122437
#
# Start of epoch 57
# Training loss (for one batch) at step 0: 1.0784565210342407
# Training loss (for one batch) at step 100: 1.0826927423477173
#
# Start of epoch 58
# Training loss (for one batch) at step 0: 1.0754495859146118
# Training loss (for one batch) at step 100: 1.0759061574935913
#
# Start of epoch 59
# Training loss (for one batch) at step 0: 1.076173186302185
# Training loss (for one batch) at step 100: 1.0850802659988403
#
# Start of epoch 60
# Training loss (for one batch) at step 0: 1.080803394317627
# Training loss (for one batch) at step 100: 1.0771880149841309
#
# Start of epoch 61
# Training loss (for one batch) at step 0: 1.0824450254440308
# Training loss (for one batch) at step 100: 1.0822075605392456
#
# Start of epoch 62
# Training loss (for one batch) at step 0: 1.0779917240142822
# Training loss (for one batch) at step 100: 1.0795389413833618
#
# Start of epoch 63
# Training loss (for one batch) at step 0: 1.0816985368728638
# Training loss (for one batch) at step 100: 1.0793341398239136
#
# Start of epoch 64
# Training loss (for one batch) at step 0: 1.0777558088302612
# Training loss (for one batch) at step 100: 1.0779575109481812
#
# Start of epoch 65
# Training loss (for one batch) at step 0: 1.0750880241394043
# Training loss (for one batch) at step 100: 1.0805168151855469
#
# Start of epoch 66
# Training loss (for one batch) at step 0: 1.077873945236206
# Training loss (for one batch) at step 100: 1.0781656503677368
#
# Start of epoch 67
# Training loss (for one batch) at step 0: 1.0738756656646729
# Training loss (for one batch) at step 100: 1.0768983364105225
#
# Start of epoch 68
# Training loss (for one batch) at step 0: 1.0792820453643799
# Training loss (for one batch) at step 100: 1.0799899101257324
#
# Start of epoch 69
# Training loss (for one batch) at step 0: 1.0825313329696655
# Training loss (for one batch) at step 100: 1.0792264938354492
#
# Start of epoch 70
# Training loss (for one batch) at step 0: 1.0787746906280518
# Training loss (for one batch) at step 100: 1.0767589807510376
#
# Start of epoch 71
# Training loss (for one batch) at step 0: 1.077336072921753
# Training loss (for one batch) at step 100: 1.0779268741607666
#
# Start of epoch 72
# Training loss (for one batch) at step 0: 1.0833250284194946
# Training loss (for one batch) at step 100: 1.0752842426300049
#
# Start of epoch 73
# Training loss (for one batch) at step 0: 1.075656533241272
# Training loss (for one batch) at step 100: 1.0748212337493896
#
# Start of epoch 74
# Training loss (for one batch) at step 0: 1.0777175426483154
# Training loss (for one batch) at step 100: 1.073927640914917
#
# Start of epoch 75
# Training loss (for one batch) at step 0: 1.0793328285217285
# Training loss (for one batch) at step 100: 1.0777888298034668
#
# Start of epoch 76
# Training loss (for one batch) at step 0: 1.0760219097137451
# Training loss (for one batch) at step 100: 1.074203372001648
#
# Start of epoch 77
# Training loss (for one batch) at step 0: 1.077238917350769
# Training loss (for one batch) at step 100: 1.0787341594696045
#
# Start of epoch 78
# Training loss (for one batch) at step 0: 1.0772418975830078
# Training loss (for one batch) at step 100: 1.074228048324585
#
# Start of epoch 79
# Training loss (for one batch) at step 0: 1.0754835605621338
# Training loss (for one batch) at step 100: 1.0755068063735962
#
# Start of epoch 80
# Training loss (for one batch) at step 0: 1.075427532196045
# Training loss (for one batch) at step 100: 1.071945309638977
#
# Start of epoch 81
# Training loss (for one batch) at step 0: 1.0718432664871216
# Training loss (for one batch) at step 100: 1.074252724647522
#
# Start of epoch 82
# Training loss (for one batch) at step 0: 1.075567603111267
# Training loss (for one batch) at step 100: 1.080325961112976
#
# Start of epoch 83
# Training loss (for one batch) at step 0: 1.0735207796096802
# Training loss (for one batch) at step 100: 1.0749388933181763
#
# Start of epoch 84
# Training loss (for one batch) at step 0: 1.0695593357086182
# Training loss (for one batch) at step 100: 1.0711946487426758
#
# Start of epoch 85
# Training loss (for one batch) at step 0: 1.0723209381103516
# Training loss (for one batch) at step 100: 1.0768351554870605
#
# Start of epoch 86
# Training loss (for one batch) at step 0: 1.072455644607544
# Training loss (for one batch) at step 100: 1.073195219039917
#
# Start of epoch 87
# Training loss (for one batch) at step 0: 1.0743745565414429
# Training loss (for one batch) at step 100: 1.0733911991119385
#
# Start of epoch 88
# Training loss (for one batch) at step 0: 1.0754121541976929
# Training loss (for one batch) at step 100: 1.0732061862945557
#
# Start of epoch 89
# Training loss (for one batch) at step 0: 1.074497938156128
# Training loss (for one batch) at step 100: 1.0761549472808838
#
# Start of epoch 90
# Training loss (for one batch) at step 0: 1.0762101411819458
# Training loss (for one batch) at step 100: 1.0782127380371094
#
# Start of epoch 91
# Training loss (for one batch) at step 0: 1.0751038789749146
# Training loss (for one batch) at step 100: 1.0761414766311646
#
# Start of epoch 92
# Training loss (for one batch) at step 0: 1.0798273086547852
# Training loss (for one batch) at step 100: 1.0715875625610352
#
# Start of epoch 93
# Training loss (for one batch) at step 0: 1.0763778686523438
# Training loss (for one batch) at step 100: 1.073269248008728
#
# Start of epoch 94
# Training loss (for one batch) at step 0: 1.0740123987197876
# Training loss (for one batch) at step 100: 1.0778741836547852
#
# Start of epoch 95
# Training loss (for one batch) at step 0: 1.0690990686416626
# Training loss (for one batch) at step 100: 1.0692039728164673
#
# Start of epoch 96
# Training loss (for one batch) at step 0: 1.0766355991363525
# Training loss (for one batch) at step 100: 1.0757497549057007
#
# Start of epoch 97
# Training loss (for one batch) at step 0: 1.0714893341064453
# Training loss (for one batch) at step 100: 1.0740920305252075
#
# Start of epoch 98
# Training loss (for one batch) at step 0: 1.0717028379440308
# Training loss (for one batch) at step 100: 1.0764845609664917
#
# Start of epoch 99
# Training loss (for one batch) at step 0: 1.0740506649017334
# Training loss (for one batch) at step 100: 1.0749977827072144
# 313/313 [==============================] - 2s 4ms/step
