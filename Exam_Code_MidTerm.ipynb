# %%
from scipy.stats import gamma, expon, norm, uniform, binom, bernoulli, poisson
from scipy.stats import ttest_ind, ttest_rel, ttest_1samp
import numpy as np

# %%
# Q1
def sigmod(x):
  return 1/(1+np.exp(-x))
input1 = 23
input2 = 12
h1 = sigmod(input1*0.2)
h2 = sigmod(input1*0.3 + input2*0.1)
h3 = sigmod(input1*0.4 + input2*0.2)
h4 = sigmod(input2*0.3)
h1*1+h2*2+h3*3+h4*4
# Out:
# 9.883025831754415

# %%
# q3
N = 10000
S = uniform.rvs(loc=0, scale=120, size=N)
E = uniform.rvs(loc=0, scale=120, size=N)
Arr_Time_Diff = np.abs(S-E)
Stay_time =np.clip(norm.rvs(loc=20, scale=5, size=N), 0, 120)
np.sum(Arr_Time_Diff <= Stay_time)/N
# Out:
# 0.3066

# %%
# q4
Decision = np.array([77, 76, 77, 85, 82, 91, 67, 81, 89, 86])
Random = np.array([68, 81, 80, 77, 93, 94, 73, 77, 89, 89])
t_statistic, p_value = ttest_rel(Random,Decision,alternative="greater")
t_statistic, p_value
# Out:
# (0.5, 0.3145356499130132)

# %%
# q5
1 - poisson.cdf(3800, 64*60)
# Out:
# 0.737556953116257

# %%
# q6
0.12/(0.12+0.32)
# Out:
# 0.2727272727272727

# %%
# q8
0.6 + 0.75 - 0.6*0.75
# Out:
# 0.9000000000000001

# %%
30/45
# Out:
# 0.6666666666666666

# %%
# 10
import pandas as pd
from scipy.stats import iqr

data = {'state': ['al', 'al', 'al', 'al', 'al', 'al', 'al', 'az', 'az', 'az', 'az', 'az', 'az', 'az', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'co', 'co', 'co', 'co', 'co', 'co', 'co', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'il', 'il', 'il', 'il', 'il', 'il', 'il', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ky', 'ky'], 'breath': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no'], 'jail': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'service': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'fatal': [839, 930, 932, 882, 1081, 1110, 1023, 724, 675, 869, 893, 1007, 937, 944, 550, 557, 525, 534, 603, 639, 610, 4615, 4573, 5020, 4960, 5253, 5504, 5390, 668, 646, 608, 579, 603, 591, 497, 515, 438, 469, 448, 450, 449, 484, 122, 110, 130, 104, 136, 146, 160, 2653, 2686, 2814, 2832, 2830, 2839, 3078, 1229, 1296, 1410, 1361, 1530, 1599, 1653, 256, 263, 242, 255, 258, 262, 257, 1651, 1526, 1547, 1534, 1596, 1660, 1837, 961, 1016, 925, 974, 1038, 1055, 1101, 480, 514, 420, 474, 441, 491, 557, 498, 411, 510, 486, 500, 491, 483, 822, 778]}
df= pd.DataFrame(data)
d_fatal = df['fatal']
np.percentile(d_fatal, 75) + iqr(d_fatal)*1.5
# Out:
# 2707.5

# %%
import pandas as pd

data = {'working': ['N','Y','Y','N','N','Y','Y', 'N','N','Y'],
        'background': ['math','math','CS', 'CS', 'CS', 'math', 'CS', 'math', 'CS','math'],
        'online':['Y','N','Y','Y','N','Y','Y','Y','N','N'],
        'result':['Pass','Pass','Fail','Pass', 'Fail','Fail','Pass','Pass', 'Fail', 'Pass']}

pd.DataFrame(data)
1-((3/5)**2 + (2/5)**2)
# Out:
# 0.48

# %%
# q12
mean = 64*60
simu = poisson.rvs(mean, size=100000)
np.percentile(simu, 90)
# Out:
# 3920.0

# %%
# Q13
entropy_0 = -(4/10)*np.log2(4/10)-(6/10)*np.log2(6/10)
entropy_math = -(1/5)*np.log2(1/5)-(4/5)*np.log2(4/5)
entropy_cs = -(3/5)*np.log2(3/5)-(2/5)*np.log2(2/5)
entropy_bk = 0.5*entropy_math + 0.5*entropy_cs
entropy_0 - entropy_bk
# Out:
# 0.12451124978365313

# %%
# 15
1-binom.cdf(5,11,0.7)
# Out:
# 0.92177520904

# %%
# Q16
import pandas as pd

data = {'state': ['al', 'al', 'al', 'al', 'al', 'al', 'al', 'az', 'az', 'az', 'az', 'az', 'az', 'az', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'co', 'co', 'co', 'co', 'co', 'co', 'co', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'il', 'il', 'il', 'il', 'il', 'il', 'il', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ky', 'ky'], 'breath': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no'], 'jail': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'service': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'fatal': [839, 930, 932, 882, 1081, 1110, 1023, 724, 675, 869, 893, 1007, 937, 944, 550, 557, 525, 534, 603, 639, 610, 4615, 4573, 5020, 4960, 5253, 5504, 5390, 668, 646, 608, 579, 603, 591, 497, 515, 438, 469, 448, 450, 449, 484, 122, 110, 130, 104, 136, 146, 160, 2653, 2686, 2814, 2832, 2830, 2839, 3078, 1229, 1296, 1410, 1361, 1530, 1599, 1653, 256, 263, 242, 255, 258, 262, 257, 1651, 1526, 1547, 1534, 1596, 1660, 1837, 961, 1016, 925, 974, 1038, 1055, 1101, 480, 514, 420, 474, 441, 491, 557, 498, 411, 510, 486, 500, 491, 483, 822, 778]}

df= pd.DataFrame(data)
df_fatal = df["fatal"]
np.percentile(df_fatal,80)
# Out:
# 1556.8000000000002

# %%
# Q17
mean = 60/64
1 - expon.cdf(2, scale=mean)
# Out:
# 0.11844182901380373

# %%
# Q19
PA = 0.42
PA_ = 1 - PA
PBA = 0.66 * PA
PBA_ = 0.25 * PA_
PB = PBA + PBA_
PB_ = 1-PB
(1-(PA+PB-PBA))/PB_
# Out:
# 0.7528556593977154

# %%
# q20
143/146
# Out:
# 0.9794520547945206

# %%
# Q21
sq15 = binom.pmf(4,14,0.25)*0.25
sq14 = binom.pmf(4,13,0.25)*0.25
sq13 = binom.pmf(4,12,0.25)*0.25
sq12 = binom.pmf(4,11,0.25)*0.25
sq11 = binom.pmf(4,10,0.25)*0.25
sq10 = binom.pmf(4,9,0.25)*0.25
sq9 = binom.pmf(4,8,0.25)*0.25
sq8 = binom.pmf(4,7,0.25)*0.25
sq7 = binom.pmf(4,6,0.25)*0.25
sq6 = binom.pmf(4,5,0.25)*0.25
sq5 = binom.pmf(5,5,0.25)
sq5+sq6+sq7+sq8+sq9+sq10+sq11+sq12+sq13+sq14+sq15
# Out:
# 0.3135140584781765

# %%
# Q22
1/(1+np.exp(-1))
# Out:
# 0.7310585786300049

# %%
# Q23
import pandas as pd

data = {'state': ['al', 'al', 'al', 'al', 'al', 'al', 'al', 'az', 'az', 'az', 'az', 'az', 'az', 'az', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ar', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'ca', 'co', 'co', 'co', 'co', 'co', 'co', 'co', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'ct', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'fl', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'id', 'id', 'id', 'id', 'id', 'id', 'id', 'il', 'il', 'il', 'il', 'il', 'il', 'il', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ia', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ks', 'ky', 'ky'], 'breath': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no'], 'jail': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'service': ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no'], 'fatal': [839, 930, 932, 882, 1081, 1110, 1023, 724, 675, 869, 893, 1007, 937, 944, 550, 557, 525, 534, 603, 639, 610, 4615, 4573, 5020, 4960, 5253, 5504, 5390, 668, 646, 608, 579, 603, 591, 497, 515, 438, 469, 448, 450, 449, 484, 122, 110, 130, 104, 136, 146, 160, 2653, 2686, 2814, 2832, 2830, 2839, 3078, 1229, 1296, 1410, 1361, 1530, 1599, 1653, 256, 263, 242, 255, 258, 262, 257, 1651, 1526, 1547, 1534, 1596, 1660, 1837, 961, 1016, 925, 974, 1038, 1055, 1101, 480, 514, 420, 474, 441, 491, 557, 498, 411, 510, 486, 500, 491, 483, 822, 778]}

df = pd.DataFrame(data)
A = df[df["jail"]=="no"]["fatal"]
B = df[df["jail"]=="yes"]["fatal"]
t_statistic, p_value = ttest_ind(A, B)
t_statistic, p_value
# Out:
# (2.133760599254604, 0.03535853239290906)

# %%
# Q4
total = (100*0.95+200*0.97+50*0.9)*3
size = 1000000
simu = norm.rvs(loc=900,scale=200,size=size)
np.sum(simu <= total)/size
# Out:
# 0.695314

# %%
# 25
A = np.array([[3,4],[0,1],[1,5]])
U,Sigma,VT = np.linalg.svd(A, full_matrices=True)
Sigma
# Out:
# array([7.02461636, 1.62934494])
